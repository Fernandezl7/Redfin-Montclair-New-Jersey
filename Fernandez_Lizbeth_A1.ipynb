# %% [markdown]
# Rename the notebook Lastname.Firstname-A1.ipynb
#
# 1. Download real estate listings for a town of your choice from redfin.com.
# 2. Load the data into a dataframe.
#
# 2 pts.

# %%
import pandas as pd
Montclair_data=pd.read_csv('redfin_2023-09-18-11-03-45.csv')

# %% [markdown]
# 3. Evaluate data types and null values among the data
#
# 2 pts.

# %%
Montclair_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 27 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   SALE TYPE                                                                                    50 non-null     object
#  1   SOLD DATE                                                                                    0 non-null      float64
#  2   PROPERTY TYPE                                                                                50 non-null     object
#  3   ADDRESS                                                                                      50 non-null     object
#  4   CITY                                                                                         50 non-null     object
# ...

# %% [markdown]
# 4. Assess the range of values (min, max, quartiles) in each numeric field.
#
# 2 pts.

# %%
Montclair_data.describe().transpose()
# Out:
#                 count          mean           std           min           25%  \
# SOLD DATE         0.0           NaN           NaN           NaN           NaN
# PRICE            50.0  1.054632e+06  6.902043e+05  2.250000e+05  6.990000e+05
# BEDS             47.0  4.127660e+00  1.918072e+00  0.000000e+00  2.500000e+00
# BATHS            47.0  2.946809e+00  1.336096e+00  1.000000e+00  2.000000e+00
# SQUARE FEET       6.0  6.288000e+03  1.164352e+04  4.350000e+02  1.017750e+03
# LOT SIZE         39.0  1.465451e+04  1.213027e+04  2.252000e+03  7.690000e+03
# YEAR BUILT       11.0  1.948545e+03  4.323046e+01  1.864000e+03  1.917500e+03
# DAYS ON MARKET   50.0  4.234000e+01  5.013069e+01  3.000000e+00  6.000000e+00
# $/SQUARE FEET     6.0  3.705000e+02  1.779919e+02  3.000000e+01  3.692500e+02
# HOA/MONTH         5.0  8.094000e+02  2.469571e+02  5.520000e+02  6.000000e+02
# MLS#             50.0  1.842426e+07  8.268838e+06  3.837114e+06  2.300966e+07
# ...

# %% [markdown]
# 5. Assess the intercorrelations among the numeric features in the dataset using a heatmap.
#
# 2 pts.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

corr = Montclair_data.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <ipython-input-9-05580c7b6a51>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = Montclair_data.corr()
# <ipython-input-9-05580c7b6a51>:6: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(corr, dtype=np.bool))
# <Axes: >

# %% [markdown]
# 6. Assess intercorrelations among bedrooms and bathrooms using a jointplot.
#
# 2 pts.

# %%
sns.jointplot(x="BEDS", y="BATHS", data=Montclair_data);

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 7)
sns.heatmap(corr, annot=True, cmap=cmap, center=0,
ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# Based on the results above answer the following questions using a separate text cell.
#
# 1. What is the target variable in this dataset? (2 pts.)
# 2. Which fields have missing values and what is the proportion of missing values for each field (2 pts.)
# 3. Are there categorical features that are represented by numbers? (2 pts.)
# 4. Which (multinomial) fields would need to be dummy coded for modeling? (2 pts.)
# 5. Is there evidence of multicollinearity (correlation among features)? (2 pts.)

# %% [markdown]
# 1.
# The target variable in this dataset is Price. We want to know the pricing of a home. However, there are features such as beds, baths, and square feet that will help us figure out the label.
#
# 2. The fields with missign values are
# *   Sold date (50/50 missing values)
# *   Beds (3/50 missing values)
# *   Baths (3/50 missing values)
# *   Square feet (44/50 missing values)
# *   Lot size (11/50 missing values)
# *   Year built (39/50 missing values)
# *   $/square feet (44/50 missing values)
# *   HOA/Month (45/50 missing values)
# *   Next open house start time (47/50 missing values)
# *   Next open house end time (47/50 missing values)
#
# 3. Yes, there are categorical features represented by numbers, which includes Postal Code and Year built
#
# 4. The fields that would have to be dummy coded for meaning would be the fields Favorite and Interested. From these fields we would be able to identify who is not interested in these properties.
#
# 5. There seems to be a multicolinearity between square feet and money/square feet. There is a strong negative correlation between the two features of -0.96. In addition, there is a strong negative correlation between HOA/month and money/square feet of -1. There are also string positive correlations between the HOA/month and square feet of 1. Baths and HOA/month also holds a strong positive correlation of 0.93. Lastly, HOA/month and Lattitude hold a strong positive correlation of 0.86. Although there are other features that hold a correlation, these seem to be the strongest multicolinearities amongst the data. Price holds the highest correlation across all the features, which is understandable since price is the target (or label) that the features are being used to obtain.
